# %% [markdown]
# # First Jupyter Notebook on Watson studio
# ___
# ## Objective:
#
# **In this final assignment, you will be able to learn:**
#
# *Creating a Jupyter Notebook in Watson Studio
#
# *Create Markdown cells
#
# ### Link to course :
#
# https://www.coursera.org/learn/open-source-tools-for-data-science/home/week/4

# %%
print (1+1)
# Out:
# 2

# %%
# graphic windows

plt.figure(3,figsize=(10,12))
plt.gcf().subplots_adjust(left = 0.2, bottom = 0.2, right = 1.5,
                          top = 0.8, wspace = 0.5, hspace = 0.5)

# Window division : 1 raw, 2 columns,
# graphic position 1
# and setting

plt.subplot(1,2,1)
plt.plot(t,z,color='b', marker = '+')
plt.title('position')
plt.grid()
plt.xlabel('t(s)')
plt.ylabel('z(m)')
plt.ylim(0)


# Window division : 2 raw, 2 columns,
# graphic en position 2
# and setting

plt.subplot(2,2,2)
plt.plot(t,vz,color='b', marker = '+')
plt.title ('speed')
plt.grid()
plt.xlabel('t(s)')
plt.ylabel('vz(m/s)')


# Window division : 2 raw, 2 columns,
# graphic en position 4
# and setting

plt.subplot(2,2,4)
plt.plot(t,az,color='b', marker = '+')
plt.title('acceleration')
plt.grid()
plt.xlabel('t(s)')
plt.ylabel('az(m/s²)')

plt.show()
